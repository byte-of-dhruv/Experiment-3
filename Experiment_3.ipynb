# %% [markdown]
# DHRUV VERULKAR
#
# 25070123162

# %%
tpl=(2, True,"Dhruv")
print(tpl)
# Out:
# (2, True, 'Dhruv')

# %%
tpl2=("apple","banana","orange")
print(tpl2[1])
print(tpl2[-2])
# Out:
# banana
# banana

# %%
tpl3=("apple","banana","orange")
tpl3[1]="kiwi"
print(tpl3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-22768901.py in <cell line: 0>()
#       1 tpl3=("apple","banana","orange")
# ----> 2 tpl3[1]="kiwi"
#       3 print(tpl3)
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl4=(10,)*5
print(tpl4)
# Out:
# (10, 10, 10, 10, 10)

# %%
list1=["symbiosis"]*5
print(list1)
# Out:
# ['symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis']

# %%
tpl5=(10)*5
print(tpl5)
# Out:
# 50

# %%
tpl6=("apple","banana","orange")
tpl7=("kiwi",)
tpl6+=tpl7
print(tpl6)
# Out:
# ('apple', 'banana', 'orange', 'kiwi')

# %%
tpl8=("apple","banana","orange")
print("before:", id(tpl8))
tpl9=("kiwi",)
tpl8+=tpl9
print(tpl8)
print("after:",id(tpl8))
# Out:
# before: 138485932623040
# ('apple', 'banana', 'orange', 'kiwi')
# after: 138485941359840

# %%
marks= (90, 82, 66, 76, 33)
print(max(marks))
print(min(marks))
print(len(marks))
print(sum(marks))
print(sorted(marks))
print(sum(marks)/len(marks))
# Out:
# 90
# 33
# 5
# 347
# [33, 66, 76, 82, 90]
# 69.4

# %%
result=("Maths", 82,"A")
subject,marks,grade = result
print("subject",subject)
print("marks",marks)
print("grade",grade)
if marks>75:
  print("distinction")
# Out:
# subject Maths
# marks 82
# grade A
# distinction

# %%
attendance=("P","P","A","P","A","P")
print("Present",attendance.count("P"))
print("Absent",attendance.count("A"))
if "A" in attendance:
  print("Guy was absent atleast once")
# Out:
# Present 4
# Absent 2
# Guy was absent atleast once
